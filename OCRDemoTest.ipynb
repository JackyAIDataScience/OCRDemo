# %%
#!pip3 install easyocr
#!pip3 install matplotlib
#!pip3 install opencv-python-headless
#!pip3 install numpy

# %%
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
image_paths = glob.glob("*.png") # *.png.

for path in image_paths:
     img = cv2.imread(path)

# instance text detector
reader = easyocr.Reader(['en'], gpu=False)

# detect text on image
text_ = reader.readtext(img)

threshold = 0.25
# draw bbox and text
for t_, t in enumerate(text_):
    print(t)

    bbox, text, score = t

    if score > threshold:
        cv2.rectangle(img, bbox[0], bbox[2], (0, 255, 0), 5)
        cv2.putText(img, text, bbox[0], cv2.FONT_HERSHEY_COMPLEX, 0.65, (255, 0, 0), 2)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# WARNING:easyocr.easyocr:Using CPU. Note: This module is much faster with a GPU.
# ([[np.int32(166), np.int32(126)], [np.int32(448), np.int32(126)], [np.int32(448), np.int32(182)], [np.int32(166), np.int32(182)]], 'ROAD CLOSED', np.float64(0.9994066640174729))
# ([[np.int32(167), np.int32(181)], [np.int32(447), np.int32(181)], [np.int32(447), np.int32(221)], [np.int32(167), np.int32(221)]], 'TO ALL PEDESTRIAN', np.float64(0.9704424028567015))
# ([[np.int32(209), np.int32(220)], [np.int32(409), np.int32(220)], [np.int32(409), np.int32(258)], [np.int32(209), np.int32(258)]], 'AND BIKE USE', np.float64(0.9281837358273326))
